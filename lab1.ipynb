# %% [markdown]
# # Lab 1 — Your first OpenAI chat workflow
#
# Select the `.venv` kernel, then run each cell with **Shift+Enter**.

# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os

openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set — copy .env.example to .env and add your key")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI

openai = OpenAI()

# %%
messages = [{"role": "user", "content": "Tell me a fun fact"}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# A fun fact: **Octopuses have three hearts**—two pump blood to the gills, and the third pumps it to the rest of the body. Also, their blood is **blue** because it uses copper-based molecules to carry oxygen.

# %%
question_prompt = (
    "Please propose a hard, challenging question to assess someone's IQ. "
    "Respond only with the question."
)
messages = [{"role": "user", "content": question_prompt}]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A clock shows 3:15. If the minute hand and hour hand continue moving at their normal rates, after how many minutes will the two hands next exactly overlap?

# %%
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# At **3:15**, the hands are not together.
#
# - **Minute hand** at 15 minutes is at \(15 \times 6 = 90^\circ\)
# - **Hour hand** at 3:15 is at \(3 \times 30 + 15 \times 0.5 = 97.5^\circ\)
#
# So the hour hand is **7.5° ahead** of the minute hand.
#
# The minute hand gains on the hour hand at a relative rate of:
#
# \[
# 6 - 0.5 = 5.5^\circ \text{ per minute}
# \]
#
# To make up \(7.5^\circ\), the time needed is:
#
# \[
# \frac{7.5}{5.5} = \frac{15}{11} \text{ minutes}
# \]
#
# So the next overlap occurs after:
#
# \[
# \boxed{\frac{15}{11}\text{ minutes}}
# \]
#
# which is about **1 minute 22 seconds**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# At **3:15**, the hands are not together.
#
# - **Minute hand** at 15 minutes is at \(15 \times 6 = 90^\circ\)
# - **Hour hand** at 3:15 is at \(3 \times 30 + 15 \times 0.5 = 97.5^\circ\)
#
# So the hour hand is **7.5° ahead** of the minute hand.
#
# The minute hand gains on the hour hand at a relative rate of:
#
# \[
# 6 - 0.5 = 5.5^\circ \text{ per minute}
# \]
#
# To make up \(7.5^\circ\), the time needed is:
#
# \[
# \frac{7.5}{5.5} = \frac{15}{11} \text{ minutes}
# \]
#
# So the next overlap occurs after:
#
# \[
# \boxed{\frac{15}{11}\text{ minutes}}
# \]
#
# which is about **1 minute 22 seconds**.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)
# Out:
# The answer is **incorrect**.
#
# Why:
# - At **3:15**, the minute hand is at **90°**.
# - The hour hand is at **97.5°**.
# - So the **hour hand is 7.5° ahead** of the minute hand.
#
# Since the minute hand moves faster, to **next overlap**, it cannot just gain **7.5°**. That would only bring it to the hour hand’s *current* position, but the hour hand keeps moving.
#
# Instead, the minute hand must gain a full **360° - 7.5° = 352.5°** on the hour hand.
#
# Relative speed:
# \[
# 6 - 0.5 = 5.5^\circ/\text{min}
# \]
#
# Time:
# \[
# \frac{352.5}{5.5}=\frac{705}{11}\text{ min}=64\frac{1}{11}\text{ min}
# \]
#
# So the next overlap occurs after:
# \[
# \boxed{\frac{705}{11}\text{ minutes}}
# \]
# which is about **64 minutes 5.45 seconds**.
#
# So the proposed answer is **incorrect**.

# %% [markdown]
# ## Exercise
#
# Chain three LLM calls:
# 1. Pick a business area worth exploring for Agentic AI
# 2. Identify a pain point in that industry
# 3. Propose an Agentic AI solution

# %%
# Call 1 — pick a business area
messages = [{"role": "user", "content": "Pick a business area worth exploring for Agentic AI. Reply with just the area."}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
business_area = response.choices[0].message.content
print(business_area)

# %%
# Call 2 — pain point in that industry
messages = [{"role": "user", "content": f"In {business_area}, describe one challenging pain point ripe for an Agentic AI solution."}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
pain_point = response.choices[0].message.content
print(pain_point)

# %%
# Call 3 — propose a solution
messages = [{"role": "user", "content": f"Business area: {business_area}\nPain point: {pain_point}\n\nPropose an Agentic AI solution."}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
print(response.choices[0].message.content)
